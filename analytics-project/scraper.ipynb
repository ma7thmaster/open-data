# %%
import pandas as pd #matches data
import json
path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/2'
alldic2 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic2.append(dict)
var7=pd.concat(alldic2)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/11'
alldicts = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldicts.append(dict)

        
var=pd.concat(alldicts)
#var
path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/16'
alldic = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic.append(dict)
var1=pd.concat(alldic)
#com = [var,var1]
#varcom = pd.concat(com)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/37'
alldic37 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic37.append(dict)
var2=pd.concat(alldic37)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/43'
alldic43 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic43.append(dict)
var3=pd.concat(alldic43)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/49'
alldic49 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic49.append(dict)
var4=pd.concat(alldic49)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/55'
alldic55 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic55.append(dict)
var5=pd.concat(alldic55)

path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/matches/72'
alldic72 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic72.append(dict)
var6=pd.concat(alldic72)

com = [var7,var,var1,var2,var3,var4,var5,var6]
matchestogether = pd.concat(com)
matchestogether=matchestogether.reset_index()
#matchestogether
matchestogether = pd.DataFrame(matchestogether)
# Out:
#       index  match_id  match_date      kick_off  \
# 0         0   3749052  2004-02-07  16:00:00.000
# 1         1   3749522  2003-12-26  13:00:00.000
# 2         2   3749246  2004-03-28  17:05:00.000
# 3         3   3749257  2004-05-15  16:00:00.000
# 4         4   3749642  2004-02-28  16:00:00.000
# ...     ...       ...         ...           ...
# 1090     47     69199  2019-06-27  21:00:00.000
# 1091     48     69258  2019-07-02  21:00:00.000
# 1092     49     69284  2019-07-03  21:00:00.000
# 1093     50     69205  2019-06-29  15:00:00.000
# 1094     51     69161  2019-06-24  18:00:00.000
#
#                                             competition  \
# 0     {'competition_id': 2, 'country_name': 'England...
# 1     {'competition_id': 2, 'country_name': 'England...
# 2     {'competition_id': 2, 'country_name': 'England...
# 3     {'competition_id': 2, 'country_name': 'England...
# 4     {'competition_id': 2, 'country_name': 'England...
# ...                                                 ...
# 1090  {'competition_id': 72, 'country_name': 'Intern...
# 1091  {'competition_id': 72, 'country_name': 'Intern...
# 1092  {'competition_id': 72, 'country_name': 'Intern...
# 1093  {'competition_id': 72, 'country_name': 'Intern...
# 1094  {'competition_id': 72, 'country_name': 'Intern...
#
#                                              season  \
# 0     {'season_id': 44, 'season_name': '2003/2004'}
# 1     {'season_id': 44, 'season_name': '2003/2004'}
# 2     {'season_id': 44, 'season_name': '2003/2004'}
# 3     {'season_id': 44, 'season_name': '2003/2004'}
# 4     {'season_id': 44, 'season_name': '2003/2004'}
# ...                                             ...
# 1090       {'season_id': 30, 'season_name': '2019'}
# 1091       {'season_id': 30, 'season_name': '2019'}
# 1092       {'season_id': 30, 'season_name': '2019'}
# 1093       {'season_id': 30, 'season_name': '2019'}
# 1094       {'season_id': 30, 'season_name': '2019'}
#
#                                               home_team  \
# 0     {'home_team_id': 46, 'home_team_name': 'Wolver...
# 1     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 2     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 3     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 4     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# ...                                                 ...
# 1090  {'home_team_id': 852, 'home_team_name': 'Norwa...
# 1091  {'home_team_id': 865, 'home_team_name': 'Engla...
# 1092  {'home_team_id': 851, 'home_team_name': 'Nethe...
# 1093  {'home_team_id': 855, 'home_team_name': 'Italy...
# 1094  {'home_team_id': 863, 'home_team_name': 'Spain...
#
#                                               away_team  home_score  \
# 0     {'away_team_id': 1, 'away_team_name': 'Arsenal...           1
# 1     {'away_team_id': 46, 'away_team_name': 'Wolver...           3
# 2     {'away_team_id': 39, 'away_team_name': 'Manche...           1
# 3     {'away_team_id': 22, 'away_team_name': 'Leices...           2
# 4     {'away_team_id': 75, 'away_team_name': 'Charlt...           2
# ...                                                 ...         ...
# 1090  {'away_team_id': 865, 'away_team_name': 'Engla...           0
# 1091  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
# 1092  {'away_team_id': 858, 'away_team_name': 'Swede...           1
# 1093  {'away_team_id': 851, 'away_team_name': 'Nethe...           0
# 1094  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
#
#       away_score match_status match_status_360                last_updated  \
# 0              3    available        scheduled            2020-07-29T05:00
# 1              0    available        scheduled            2020-07-29T05:00
# 2              1    available        scheduled            2020-07-29T05:00
# 3              1    available        scheduled  2020-08-30T08:12:14.579037
# 4              1    available        scheduled            2020-07-29T05:00
# ...          ...          ...              ...                         ...
# 1090           3    available        scheduled            2020-07-29T05:00
# 1091           2    available        scheduled            2020-07-29T05:00
# 1092           0    available        scheduled            2020-07-29T05:00
# 1093           2    available        scheduled            2020-07-29T05:00
# 1094           2    available        scheduled            2020-07-29T05:00
#
#              last_updated_360  \
# 0     2021-06-13T16:17:31.694
# 1     2021-06-13T16:17:31.694
# 2     2021-06-13T16:17:31.694
# 3     2021-06-13T16:17:31.694
# 4     2021-06-13T16:17:31.694
# ...                       ...
# 1090  2021-06-13T16:17:31.694
# 1091  2021-06-13T16:17:31.694
# 1092  2021-06-13T16:17:31.694
# 1093  2021-06-13T16:17:31.694
# 1094  2021-06-13T16:17:31.694
#
#                                                metadata  match_week  \
# 0     {'data_version': '1.1.0', 'shot_fidelity_versi...           2
# 1     {'data_version': '1.1.0', 'shot_fidelity_versi...          18
# 2     {'data_version': '1.1.0', 'shot_fidelity_versi...          30
# 3     {'data_version': '1.1.0', 'shot_fidelity_versi...          38
# 4     {'data_version': '1.1.0', 'shot_fidelity_versi...          27
# ...                                                 ...         ...
# 1090  {'data_version': '1.1.0', 'shot_fidelity_versi...           5
# 1091  {'data_version': '1.1.0', 'shot_fidelity_versi...           6
# 1092  {'data_version': '1.1.0', 'shot_fidelity_versi...           6
# 1093  {'data_version': '1.1.0', 'shot_fidelity_versi...           5
# 1094  {'data_version': '1.1.0', 'shot_fidelity_versi...           4
#
#                         competition_stage  \
# 0     {'id': 1, 'name': 'Regular Season'}
# 1     {'id': 1, 'name': 'Regular Season'}
# 2     {'id': 1, 'name': 'Regular Season'}
# 3     {'id': 1, 'name': 'Regular Season'}
# 4     {'id': 1, 'name': 'Regular Season'}
# ...                                   ...
# 1090  {'id': 1, 'name': 'Regular Season'}
# 1091    {'id': 15, 'name': 'Semi-finals'}
# 1092    {'id': 15, 'name': 'Semi-finals'}
# 1093  {'id': 1, 'name': 'Regular Season'}
# 1094    {'id': 33, 'name': 'Round of 16'}
#
#                                                 stadium  \
# 0     {'id': 217, 'name': 'Molineux Stadium (Wolverh...
# 1     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 2     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 3     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 4     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# ...                                                 ...
# 1090  {'id': 230, 'name': 'Stade Océane', 'country':...
# 1091  {'id': 193, 'name': 'Groupama Stadium', 'count...
# 1092  {'id': 193, 'name': 'Groupama Stadium', 'count...
# 1093  {'id': 231, 'name': 'Stade du Hainaut', 'count...
# 1094  {'id': 232, 'name': 'Stade Auguste-Delaune II ...
#
#                                                 referee
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1090  {'id': 1638, 'name': 'Lucila Venegas Montes', ...
# 1091                                               None
# 1092  {'id': 1627, 'name': 'Marie-Soleil Beaudoin', ...
# 1093  {'id': 1632, 'name': 'Claudia Umpiérrez', 'cou...
# 1094  {'id': 721, 'name': 'Katalin Kulcsar', 'countr...
#
# [1095 rows x 19 columns]

# %%
matchestogether.to_pickle('pickle_matches')

# %%
import pandas as pd
pd.read_pickle('pickle_matches')
# Out:
#       index  match_id  match_date      kick_off  \
# 0         0   3749052  2004-02-07  16:00:00.000
# 1         1   3749522  2003-12-26  13:00:00.000
# 2         2   3749246  2004-03-28  17:05:00.000
# 3         3   3749257  2004-05-15  16:00:00.000
# 4         4   3749642  2004-02-28  16:00:00.000
# ...     ...       ...         ...           ...
# 1090     47     69199  2019-06-27  21:00:00.000
# 1091     48     69258  2019-07-02  21:00:00.000
# 1092     49     69284  2019-07-03  21:00:00.000
# 1093     50     69205  2019-06-29  15:00:00.000
# 1094     51     69161  2019-06-24  18:00:00.000
#
#                                             competition  \
# 0     {'competition_id': 2, 'country_name': 'England...
# 1     {'competition_id': 2, 'country_name': 'England...
# 2     {'competition_id': 2, 'country_name': 'England...
# 3     {'competition_id': 2, 'country_name': 'England...
# 4     {'competition_id': 2, 'country_name': 'England...
# ...                                                 ...
# 1090  {'competition_id': 72, 'country_name': 'Intern...
# 1091  {'competition_id': 72, 'country_name': 'Intern...
# 1092  {'competition_id': 72, 'country_name': 'Intern...
# 1093  {'competition_id': 72, 'country_name': 'Intern...
# 1094  {'competition_id': 72, 'country_name': 'Intern...
#
#                                              season  \
# 0     {'season_id': 44, 'season_name': '2003/2004'}
# 1     {'season_id': 44, 'season_name': '2003/2004'}
# 2     {'season_id': 44, 'season_name': '2003/2004'}
# 3     {'season_id': 44, 'season_name': '2003/2004'}
# 4     {'season_id': 44, 'season_name': '2003/2004'}
# ...                                             ...
# 1090       {'season_id': 30, 'season_name': '2019'}
# 1091       {'season_id': 30, 'season_name': '2019'}
# 1092       {'season_id': 30, 'season_name': '2019'}
# 1093       {'season_id': 30, 'season_name': '2019'}
# 1094       {'season_id': 30, 'season_name': '2019'}
#
#                                               home_team  \
# 0     {'home_team_id': 46, 'home_team_name': 'Wolver...
# 1     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 2     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 3     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 4     {'home_team_id': 1, 'home_team_name': 'Arsenal...
# ...                                                 ...
# 1090  {'home_team_id': 852, 'home_team_name': 'Norwa...
# 1091  {'home_team_id': 865, 'home_team_name': 'Engla...
# 1092  {'home_team_id': 851, 'home_team_name': 'Nethe...
# 1093  {'home_team_id': 855, 'home_team_name': 'Italy...
# 1094  {'home_team_id': 863, 'home_team_name': 'Spain...
#
#                                               away_team  home_score  \
# 0     {'away_team_id': 1, 'away_team_name': 'Arsenal...           1
# 1     {'away_team_id': 46, 'away_team_name': 'Wolver...           3
# 2     {'away_team_id': 39, 'away_team_name': 'Manche...           1
# 3     {'away_team_id': 22, 'away_team_name': 'Leices...           2
# 4     {'away_team_id': 75, 'away_team_name': 'Charlt...           2
# ...                                                 ...         ...
# 1090  {'away_team_id': 865, 'away_team_name': 'Engla...           0
# 1091  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
# 1092  {'away_team_id': 858, 'away_team_name': 'Swede...           1
# 1093  {'away_team_id': 851, 'away_team_name': 'Nethe...           0
# 1094  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
#
#       away_score match_status match_status_360                last_updated  \
# 0              3    available        scheduled            2020-07-29T05:00
# 1              0    available        scheduled            2020-07-29T05:00
# 2              1    available        scheduled            2020-07-29T05:00
# 3              1    available        scheduled  2020-08-30T08:12:14.579037
# 4              1    available        scheduled            2020-07-29T05:00
# ...          ...          ...              ...                         ...
# 1090           3    available        scheduled            2020-07-29T05:00
# 1091           2    available        scheduled            2020-07-29T05:00
# 1092           0    available        scheduled            2020-07-29T05:00
# 1093           2    available        scheduled            2020-07-29T05:00
# 1094           2    available        scheduled            2020-07-29T05:00
#
#              last_updated_360  \
# 0     2021-06-13T16:17:31.694
# 1     2021-06-13T16:17:31.694
# 2     2021-06-13T16:17:31.694
# 3     2021-06-13T16:17:31.694
# 4     2021-06-13T16:17:31.694
# ...                       ...
# 1090  2021-06-13T16:17:31.694
# 1091  2021-06-13T16:17:31.694
# 1092  2021-06-13T16:17:31.694
# 1093  2021-06-13T16:17:31.694
# 1094  2021-06-13T16:17:31.694
#
#                                                metadata  match_week  \
# 0     {'data_version': '1.1.0', 'shot_fidelity_versi...           2
# 1     {'data_version': '1.1.0', 'shot_fidelity_versi...          18
# 2     {'data_version': '1.1.0', 'shot_fidelity_versi...          30
# 3     {'data_version': '1.1.0', 'shot_fidelity_versi...          38
# 4     {'data_version': '1.1.0', 'shot_fidelity_versi...          27
# ...                                                 ...         ...
# 1090  {'data_version': '1.1.0', 'shot_fidelity_versi...           5
# 1091  {'data_version': '1.1.0', 'shot_fidelity_versi...           6
# 1092  {'data_version': '1.1.0', 'shot_fidelity_versi...           6
# 1093  {'data_version': '1.1.0', 'shot_fidelity_versi...           5
# 1094  {'data_version': '1.1.0', 'shot_fidelity_versi...           4
#
#                         competition_stage  \
# 0     {'id': 1, 'name': 'Regular Season'}
# 1     {'id': 1, 'name': 'Regular Season'}
# 2     {'id': 1, 'name': 'Regular Season'}
# 3     {'id': 1, 'name': 'Regular Season'}
# 4     {'id': 1, 'name': 'Regular Season'}
# ...                                   ...
# 1090  {'id': 1, 'name': 'Regular Season'}
# 1091    {'id': 15, 'name': 'Semi-finals'}
# 1092    {'id': 15, 'name': 'Semi-finals'}
# 1093  {'id': 1, 'name': 'Regular Season'}
# 1094    {'id': 33, 'name': 'Round of 16'}
#
#                                                 stadium  \
# 0     {'id': 217, 'name': 'Molineux Stadium (Wolverh...
# 1     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 2     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 3     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# 4     {'id': 1000243, 'name': 'Highbury Stadium', 'c...
# ...                                                 ...
# 1090  {'id': 230, 'name': 'Stade Océane', 'country':...
# 1091  {'id': 193, 'name': 'Groupama Stadium', 'count...
# 1092  {'id': 193, 'name': 'Groupama Stadium', 'count...
# 1093  {'id': 231, 'name': 'Stade du Hainaut', 'count...
# 1094  {'id': 232, 'name': 'Stade Auguste-Delaune II ...
#
#                                                 referee
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1090  {'id': 1638, 'name': 'Lucila Venegas Montes', ...
# 1091                                                NaN
# 1092  {'id': 1627, 'name': 'Marie-Soleil Beaudoin', ...
# 1093  {'id': 1632, 'name': 'Claudia Umpiérrez', 'cou...
# 1094  {'id': 721, 'name': 'Katalin Kulcsar', 'countr...
#
# [1095 rows x 19 columns]

# %%
import pandas as pd #lineups
path_to_jsonfiles = '/Users/matthewvoss/SoccerProjectFixed/open-data/data/lineups'
alldicline = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldicline.append(dict)
varlineup=pd.concat(alldicline)
varlineup = varlineup.reset_index()
varlineup
varlineup.to_pickle('pickle_lineup')

# %%
shortened_matches = pd.read_pickle('pickle_matches')
shortened_matches = shortened_matches[['match_id','home_team','away_team','home_score','away_score']]
shortened_matches
# Out:
#       match_id                                          home_team  \
# 0      3749052  {'home_team_id': 46, 'home_team_name': 'Wolver...
# 1      3749522  {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 2      3749246  {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 3      3749257  {'home_team_id': 1, 'home_team_name': 'Arsenal...
# 4      3749642  {'home_team_id': 1, 'home_team_name': 'Arsenal...
# ...        ...                                                ...
# 1090     69199  {'home_team_id': 852, 'home_team_name': 'Norwa...
# 1091     69258  {'home_team_id': 865, 'home_team_name': 'Engla...
# 1092     69284  {'home_team_id': 851, 'home_team_name': 'Nethe...
# 1093     69205  {'home_team_id': 855, 'home_team_name': 'Italy...
# 1094     69161  {'home_team_id': 863, 'home_team_name': 'Spain...
#
#                                               away_team  home_score  \
# 0     {'away_team_id': 1, 'away_team_name': 'Arsenal...           1
# 1     {'away_team_id': 46, 'away_team_name': 'Wolver...           3
# 2     {'away_team_id': 39, 'away_team_name': 'Manche...           1
# 3     {'away_team_id': 22, 'away_team_name': 'Leices...           2
# 4     {'away_team_id': 75, 'away_team_name': 'Charlt...           2
# ...                                                 ...         ...
# 1090  {'away_team_id': 865, 'away_team_name': 'Engla...           0
# 1091  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
# 1092  {'away_team_id': 858, 'away_team_name': 'Swede...           1
# 1093  {'away_team_id': 851, 'away_team_name': 'Nethe...           0
# 1094  {'away_team_id': 1214, 'away_team_name': 'Unit...           1
#
#       away_score
# 0              3
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1090           3
# 1091           2
# 1092           0
# 1093           2
# 1094           2
#
# [1095 rows x 5 columns]

# %%
def breaker(text):
    ending = text.find('.json')
    return text[:ending]
test = 'hello I like water.json'
test2='7298.json'
a=breaker(test2)
int(a)
# Out:
# 7298

# %%
dictionary = []
shortened_matches['match_id']
for i in range(1095):
    temp = pd.read_json('/Users/matthewvoss/SoccerProjectFixed/open-data/data/events/' + str(shortened_matches.at[i,'match_id']) + '.json')
    temp['match_id']=shortened_matches.at[i,'match_id']
    temp['match_id']=shortened_matches.at[i,'match_id']
    temp['home_team']=shortened_matches.at[i,'home_team'].get('home_team_name')
    temp['away_team']=shortened_matches.at[i,'away_team'].get('away_team_name')
    temp['home_score']=shortened_matches.at[i,'home_score']
    temp['away_score']=shortened_matches.at[i,'away_score']
    dictionary.append(temp)
fullData = pd.concat(dictionary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-07f1e457df1b> in <module>
#       2 shortened_matches['match_id']
#       3 for i in range(1095):
# ----> 4     temp = pd.read_json('/Users/matthewvoss/SoccerProjectFixed/open-data/data/events/' + str(shortened_matches.at[i,'match_id']) + '.json')
#       5     temp['match_id']=shortened_matches.at[i,'match_id']
#       6     temp['match_id']=shortened_matches.at[i,'match_id']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options)
#     561
#     562     with json_reader:
# --> 563         return json_reader.read()
#     564
#     565
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     692                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     693         else:
# --> 694             obj = self._get_object_parser(self.data)
#     695         self.close()
#     696         return obj
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     714         obj = None
#     715         if typ == "frame":
# --> 716             obj = FrameParser(json, **kwargs).parse()
#     717
#     718         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#     835         if self.convert_axes:
#     836             self._convert_axes()
# --> 837         self._try_convert_types()
#     838         return self.obj
#     839
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _try_convert_types(self)
#    1130             return
#    1131         if self.convert_dates:
# -> 1132             self._try_convert_dates()
#    1133
#    1134         self._process_converter(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _try_convert_dates(self)
#    1165             return False
#    1166
# -> 1167         self._process_converter(
#    1168             lambda col, c: self._try_convert_to_date(c),
#    1169             lambda col, c: (
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _process_converter(self, f, filt)
#    1113         for i, (col, c) in enumerate(obj.items()):
#    1114             if filt(col, c):
# -> 1115                 new_data, result = f(col, c)
#    1116                 if result:
#    1117                     c = new_data
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in <lambda>(col, c)
#    1166
#    1167         self._process_converter(
# -> 1168             lambda col, c: self._try_convert_to_date(c),
#    1169             lambda col, c: (
#    1170                 (self.keep_default_dates and is_ok(col)) or col in convert_dates
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _try_convert_to_date(self, data)
#     970         for date_unit in date_units:
#     971             try:
# --> 972                 new_data = to_datetime(new_data, errors="raise", unit=date_unit)
#     973             except (ValueError, OverflowError, TypeError):
#     974                 continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     799                 result = result.tz_localize(tz)
#     800     elif isinstance(arg, ABCSeries):
# --> 801         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     802         if not cache_array.empty:
#     803             result = arg.map(cache_array)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     176         unique_dates = unique(arg)
#     177         if len(unique_dates) < len(arg):
# --> 178             cache_dates = convert_listlike(unique_dates, format)
#     179             cache_array = Series(cache_dates, index=unique_dates)
#     180     return cache_array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     343         else:
#     344
# --> 345             result, tz_parsed = tslib.array_with_unit_to_datetime(
#     346                 arg, unit, errors=errors
#     347             )
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644                                                       second=0, microsecond=0)
#     645
# --> 646         res, skipped_tokens = self._parse(timestr, **kwargs)
#     647
#     648         if res is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     723
#     724         res = self._result()
# --> 725         l = _timelex.split(timestr)         # Splits the timestr into tokens
#     726
#     727         skipped_idxs = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in split(cls, s)
#     205     @classmethod
#     206     def split(cls, s):
# --> 207         return list(cls(s))
#     208
#     209     @classmethod
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in __next__(self)
#     194
#     195     def __next__(self):
# --> 196         token = self.get_token()
#     197         if token is None:
#     198             raise StopIteration
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in get_token(self)
#     114                     nextchar = self.instream.read(1)
#     115
# --> 116             if not nextchar:
#     117                 self.eof = True
#     118                 break
#
# KeyboardInterrupt:

# %%
import pandas as pd
shortened_matches = pd.read_pickle('pickle_matches')
shortened_matches = shortened_matches[['match_id','home_team','away_team','home_score','away_score','match_date']]
#shortened_matches['year']=shortened_matches['match_date']
def breaker(text):
    ending = text.find('-')
    return text[:ending]
diction = []
diction2 = []
for i in range(len(shortened_matches['match_id'])):
    temp = shortened_matches['match_date'].get(i)
    diction.append(temp)
for i in range(len(shortened_matches)):
    temp2 = breaker(diction[i])
    diction2.append(temp2)
shortened_matches['year']=diction2
shortened_matches_2019 = shortened_matches[shortened_matches['year']=='2019']
dictionary = []
for i in range(len(shortened_matches_2019)):
    temp3 = pd.read_json('/Users/matthewvoss/SoccerProjectFixed/open-data/data/events/' + str(shortened_matches['match_id'].values[i]) + '.json')
    temp3['home_team']=shortened_matches_2019['home_team'].values[i].get('home_team_name')
    temp3['away_team']=shortened_matches_2019['away_team'].values[i].get('away_team_name')
    temp3['home_score']=shortened_matches_2019['home_score'].values[i]
    temp3['away_score']=shortened_matches_2019['away_score'].values[i]
    temp3['match_id']=shortened_matches_2019['match_id'].values[i]
    dictionary.append(temp3)
df = pd.concat(dictionary)
df
# Out:
#                                         id  index  period  \
# 0     3b20dc57-5cb7-46a8-bccb-b09d984478d7      1       1
# 1     61306f72-bec9-466f-9d43-c1152531323c      2       1
# 2     98964276-7c4e-4067-975a-2f7a07665ad8      3       1
# 3     691cd9cc-9e81-4ba1-83b9-87fc0617fab0      4       1
# 4     3870b202-0c05-4fe2-9729-e186bd4d1808      5       1
# ...                                    ...    ...     ...
# 3613  bc8bd9d3-3b69-4ae4-936e-37bbbd498690   3614       2
# 3614  6a1d948b-4d3e-4d86-82d8-41432367ae9e   3615       2
# 3615  7a53ad83-61de-4dbb-b24c-97aa47310858   3616       2
# 3616  f0eb6c34-b2ae-4ec7-a3f8-e21d643d7b99   3617       2
# 3617  adb2d7f4-0c36-498b-9319-92ea2b3b4a5c   3618       2
#
#                    timestamp  minute  second  \
# 0    2021-11-28 00:00:00.000       0       0
# 1    2021-11-28 00:00:00.000       0       0
# 2    2021-11-28 00:00:00.000       0       0
# 3    2021-11-28 00:00:00.000       0       0
# 4    2021-11-28 00:00:00.675       0       0
# ...                      ...     ...     ...
# 3613 2021-11-28 00:47:49.376      92      49
# 3614 2021-11-28 00:47:57.105      92      57
# 3615 2021-11-28 00:47:58.818      92      58
# 3616 2021-11-28 00:48:05.235      93       5
# 3617 2021-11-28 00:48:05.235      93       5
#
#                                      type  possession  \
# 0       {'id': 35, 'name': 'Starting XI'}           1
# 1       {'id': 35, 'name': 'Starting XI'}           1
# 2        {'id': 18, 'name': 'Half Start'}           1
# 3        {'id': 18, 'name': 'Half Start'}           1
# 4              {'id': 30, 'name': 'Pass'}           2
# ...                                   ...         ...
# 3613   {'id': 2, 'name': 'Ball Recovery'}         181
# 3614           {'id': 30, 'name': 'Pass'}         181
# 3615  {'id': 42, 'name': 'Ball Receipt*'}         181
# 3616       {'id': 34, 'name': 'Half End'}         181
# 3617       {'id': 34, 'name': 'Half End'}         181
#
#                                     possession_team  \
# 0     {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 1     {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 2     {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 3     {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 4                      {'id': 1, 'name': 'Arsenal'}
# ...                                             ...
# 3613               {'id': 217, 'name': 'Barcelona'}
# 3614               {'id': 217, 'name': 'Barcelona'}
# 3615               {'id': 217, 'name': 'Barcelona'}
# 3616               {'id': 217, 'name': 'Barcelona'}
# 3617               {'id': 217, 'name': 'Barcelona'}
#
#                             play_pattern  ...      home_team  \
# 0      {'id': 1, 'name': 'Regular Play'}  ...        Sevilla
# 1      {'id': 1, 'name': 'Regular Play'}  ...        Sevilla
# 2      {'id': 1, 'name': 'Regular Play'}  ...        Sevilla
# 3      {'id': 1, 'name': 'Regular Play'}  ...        Sevilla
# 4     {'id': 9, 'name': 'From Kick Off'}  ...        Sevilla
# ...                                  ...  ...            ...
# 3613  {'id': 4, 'name': 'From Throw In'}  ...  Spain Women's
# 3614  {'id': 4, 'name': 'From Throw In'}  ...  Spain Women's
# 3615  {'id': 4, 'name': 'From Throw In'}  ...  Spain Women's
# 3616  {'id': 4, 'name': 'From Throw In'}  ...  Spain Women's
# 3617  {'id': 4, 'name': 'From Throw In'}  ...  Spain Women's
#
#                   away_team home_score away_score  match_id 50_50 half_start  \
# 0                 Barcelona          2          4     16190   NaN        NaN
# 1                 Barcelona          2          4     16190   NaN        NaN
# 2                 Barcelona          2          4     16190   NaN        NaN
# 3                 Barcelona          2          4     16190   NaN        NaN
# 4                 Barcelona          2          4     16190   NaN        NaN
# ...                     ...        ...        ...       ...   ...        ...
# 3613  United States Women's          1          2     69161   NaN        NaN
# 3614  United States Women's          1          2     69161   NaN        NaN
# 3615  United States Women's          1          2     69161   NaN        NaN
# 3616  United States Women's          1          2     69161   NaN        NaN
# 3617  United States Women's          1          2     69161   NaN        NaN
#
#      injury_stoppage half_end player_off
# 0                NaN      NaN        NaN
# 1                NaN      NaN        NaN
# 2                NaN      NaN        NaN
# 3                NaN      NaN        NaN
# 4                NaN      NaN        NaN
# ...              ...      ...        ...
# 3613             NaN      NaN        NaN
# 3614             NaN      NaN        NaN
# 3615             NaN      NaN        NaN
# 3616             NaN      NaN        NaN
# 3617             NaN      NaN        NaN
#
# [679473 rows x 47 columns]

# %%
dfshotsonly = df.dropna(subset=['shot'])
dfshotsonly['shot'].values
# Out:
# array([{'statsbomb_xg': 0.18677612000000002, 'end_location': [120.0, 43.8, 0.5], 'key_pass_id': '8267672c-804d-4702-ac50-d501f2eb8fe2', 'body_part': {'id': 40, 'name': 'Right Foot'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 97, 'name': 'Goal'}, 'first_time': True, 'technique': {'id': 91, 'name': 'Half Volley'}, 'freeze_frame': [{'location': [104.0, 29.4], 'player': {'id': 24765, 'name': 'Denis Irwin'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': False}, {'location': [101.9, 50.4], 'player': {'id': 40304, 'name': 'Lee Naylor'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': False}, {'location': [97.8, 39.3], 'player': {'id': 40313, 'name': 'Colin Cameron'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [105.2, 39.6], 'player': {'id': 40312, 'name': 'Paul Butler'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [107.2, 31.4], 'player': {'id': 40314, 'name': 'Jody Craddock'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [114.7, 37.1], 'player': {'id': 40319, 'name': 'Paul Jones'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [106.8, 27.7], 'player': {'id': 12529, 'name': 'Ashley Cole'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': True}, {'location': [98.9, 35.0], 'player': {'id': 19312, 'name': 'Robert Pirès '}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'teammate': True}]},
#        {'statsbomb_xg': 0.031963106000000005, 'end_location': [118.7, 38.9, 2.3], 'key_pass_id': '428a30a1-5f57-4b04-ab1b-5f0a3e189d36', 'technique': {'id': 93, 'name': 'Normal'}, 'body_part': {'id': 40, 'name': 'Right Foot'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 100, 'name': 'Saved'}, 'freeze_frame': [{'location': [110.2, 41.8], 'player': {'id': 15515, 'name': 'Patrick Vieira'}, 'position': {'id': 9, 'name': 'Right Def
#        ...,
#        {'statsbomb_xg': 0.042451832, 'end_location': [118.1, 42.6, 0.8], 'key_pass_id': '10a1d48b-001c-4f19-911f-7401ff581090', 'technique': {'id': 93, 'name': 'Normal'}, 'body_part': {'id': 37, 'name': 'Head'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 100, 'name': 'Saved'}, 'freeze_frame': [{'location': [109.3, 37.3], 'player': {'id': 6671, 'name': 'Asier Illarramendi Andonegi'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': False}, {'location': [112.5, 32.4], 'player': {'id': 6605, 'name': 'Joseba Zaldúa Bengoetxea'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': False}, {'location': [112.8, 41.2], 'player': {'id': 16622, 'name': 'Mikel González de Martín Martínez'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [110.4, 46.1], 'player': {'id': 16539, 'name': 'Diego Antonio Reyes Rosales'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [107.1, 24.0], 'player': {'id': 6690, 'name': 'Xabier Prieto Argarate'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': False}, {'location': [104.9, 30.4], 'player': {'id': 6770, 'name': 'Esteban Félix Granero Molina'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': False}, {'location': [118.1, 41.2], 'player': {'id': 6694, 'name': 'Gerónimo Rulli'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [109.5, 59.9], 'player': {'id': 6674, 'name': 'Alberto De La Bella Madureño'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': False}, {'location': [104.2, 48.4], 'player': {'id': 6899, 'name': 'Rubén Pardo Gutiérrez'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': False}, {'location': [111.8, 41.1], 'player': {'id': 6616, 'name': 'Munir El Haddadi Mohamed'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': True}, {'location': [114.1, 43.0], 'player': {'id': 5213, 'name': 'Gerard Piqué Bernabéu'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': True}, {'location': [104.1, 33.6], 'player': {'id': 5216, 'name': 'Andrés Iniesta Luján'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [108.0, 30.5], 'player': {'id': 4320, 'name': 'Neymar da Silva Santos Junior'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': True}, {'location': [94.4, 17.3], 'player': {'id': 5211, 'name': 'Jordi Alba Ramos'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': True}, {'location': [107.4, 64.9], 'player': {'id': 4324, 'name': 'Daniel Alves da Silva'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': True}]},
#        {'statsbomb_xg': 0.16987328000000002, 'end_location': [115.0, 39.2, 0.7000000000000001], 'key_pass_id': '23a808bc-c4d9-4582-95e5-f2b35e6ac9d6', 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 100, 'name': 'Saved'}, 'technique': {'id': 93, 'name': 'Normal'}, 'body_part': {'id': 38, 'name': 'Left Foot'}, 'freeze_frame': [{'location': [87.1, 18.9], 'player': {'id': 6690, 'name': 'Xabier Prieto Arg
}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [108.8, 35.9], 'player': {'id': 6671, 'name': 'Asier Illarramendi Andonegi'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': False}, {'location': [108.5, 38.9], 'player': {'id': 16539, 'name': 'Diego Antonio Reyes Rosales'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [104.4, 45.5], 'player': {'id': 6674, 'name': 'Alberto De La Bella Madureño'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': False}, {'location': [116.9, 39.5], 'player': {'id': 6694, 'name': 'Gerónimo Rulli'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [100.9, 37.2], 'player': {'id': 10754, 'name': 'Héctor Hernández Ortega'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': False}, {'location': [102.8, 42.7], 'player': {'id': 6899, 'name': 'Rubén Pardo Gutiérrez'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': False}, {'location': [106.3, 25.4], 'player': {'id': 4320, 'name': 'Neymar da Silva Santos Junior'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': True}, {'location': [108.4, 22.1], 'player': {'id': 6616, 'name': 'Munir El Haddadi Mohamed'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': True}, {'location': [107.5, 44.7], 'player': {'id': 5213, 'name': 'Gerard Piqué Bernabéu'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': True}, {'location': [110.1, 41.2], 'player': {'id': 5211, 'name': 'Jordi Alba Ramos'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': True}, {'location': [98.4, 53.8], 'player': {'id': 5470, 'name': 'Ivan Rakitić'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [96.0, 63.4], 'player': {'id': 4324, 'name': 'Daniel Alves da Silva'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': True}]}],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

y = df['match_id'].values
X = df.iloc[:, df.columns!='match_id']

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42, stratify=y)

# %%
y_train.shape
# Out:
# (475631,)

# %%
from sklearn.model_selection import GroupShuffleSplit
train_inds, test_inds = next(GroupShuffleSplit(test_size=.20, n_splits=2, random_state = 42).split(df, groups=df['match_id']))

train = df.iloc[train_inds]
test = df.iloc[test_inds]

# %%
train.shape
# Out:
# (22177, 47)

# %%
test.shape
# Out:
# (5564, 47)

# %%
#So I have discovered that the shot column when it isn't NaN is really useful
#I just kept only the rows with no NaN values and use those to make our model
#Since Stats bomb gives us a Xg already what if we try and make a model that performs
#better than their Xg in order to help people make bets in soccer.
import pandas as pd
shortened_matches = pd.read_pickle('pickle_matches')
shortened_matches = shortened_matches[['match_id','home_team','away_team','home_score','away_score','match_date']]
dictionary=[]
for i in range(len(shortened_matches)):
    temp4 = pd.read_json('/Users/matthewvoss/SoccerProjectFixed/open-data/data/events/' + str(shortened_matches['match_id'].values[i]) + '.json')
    temp4=temp4.dropna(subset=['shot'])
    temp4['home_team']=shortened_matches['home_team'].values[i].get('home_team_name')
    temp4['away_team']=shortened_matches['away_team'].values[i].get('away_team_name')
    temp4['home_score']=shortened_matches['home_score'].values[i]
    temp4['away_score']=shortened_matches['away_score'].values[i]
    temp4['match_id']=shortened_matches['match_id'].values[i]
    dictionary.append(temp4)
df = pd.concat(dictionary)
df
# Out:
#                                         id  index  period  \
# 359   b69245a8-00da-4bac-8766-7b1d7548acbc    360       1
# 474   86c1c1ba-71a9-401e-a11e-c43716c2f543    475       1
# 479   83491870-daa3-4174-b59a-f96d63c9881d    480       1
# 507   03f7b8ae-8f2d-448f-a75e-fb3aa350cb91    508       1
# 717   9d164056-1ab0-4e31-adfc-2c806537c0bd    718       1
# ...                                    ...    ...     ...
# 2059  3e767b66-7e5a-428e-a4a8-26af57a7639b   2060       2
# 2211  97ea84d3-d429-48a4-9664-a2c2d489da12   2212       2
# 2227  746bc451-30af-477a-b824-293543017741   2228       2
# 2432  a5a87567-a946-4860-9f5f-75436339c59d   2433       2
# 2504  b770310f-94c0-4397-ae2e-98d4ce86ace2   2505       2
#
#                    timestamp  minute  second                        type  \
# 359  2021-11-28 00:08:11.523       8      11  {'id': 16, 'name': 'Shot'}
# 474  2021-11-28 00:12:19.239      12      19  {'id': 16, 'name': 'Shot'}
# 479  2021-11-28 00:12:23.131      12      23  {'id': 16, 'name': 'Shot'}
# 507  2021-11-28 00:13:45.318      13      45  {'id': 16, 'name': 'Shot'}
# 717  2021-11-28 00:20:20.793      20      20  {'id': 16, 'name': 'Shot'}
# ...                      ...     ...     ...                         ...
# 2059 2021-11-28 00:14:29.178      59      29  {'id': 16, 'name': 'Shot'}
# 2211 2021-11-28 00:19:07.871      64       7  {'id': 16, 'name': 'Shot'}
# 2227 2021-11-28 00:19:59.455      64      59  {'id': 16, 'name': 'Shot'}
# 2432 2021-11-28 00:30:36.196      75      36  {'id': 16, 'name': 'Shot'}
# 2504 2021-11-28 00:33:35.925      78      35  {'id': 16, 'name': 'Shot'}
#
#       possession                                possession_team  \
# 359           22                   {'id': 1, 'name': 'Arsenal'}
# 474           28                   {'id': 1, 'name': 'Arsenal'}
# 479           28                   {'id': 1, 'name': 'Arsenal'}
# 507           32  {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 717           48  {'id': 46, 'name': 'Wolverhampton Wanderers'}
# ...          ...                                            ...
# 2059         118  {'id': 1214, 'name': 'United States Women's'}
# 2211         126  {'id': 1214, 'name': 'United States Women's'}
# 2227         128           {'id': 863, 'name': 'Spain Women's'}
# 2432         138  {'id': 1214, 'name': 'United States Women's'}
# 2504         143  {'id': 1214, 'name': 'United States Women's'}
#
#                              play_pattern  ...                home_team  \
# 359    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 474    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 479    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 507   {'id': 3, 'name': 'From Free Kick'}  ...  Wolverhampton Wanderers
# 717   {'id': 3, 'name': 'From Free Kick'}  ...  Wolverhampton Wanderers
# ...                                   ...  ...                      ...
# 2059  {'id': 3, 'name': 'From Free Kick'}  ...            Spain Women's
# 2211   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
# 2227   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
# 2432           {'id': 5, 'name': 'Other'}  ...            Spain Women's
# 2504   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
#
#                   away_team home_score away_score  match_id 50_50 half_start  \
# 359                 Arsenal          1          3   3749052   NaN        NaN
# 474                 Arsenal          1          3   3749052   NaN        NaN
# 479                 Arsenal          1          3   3749052   NaN        NaN
# 507                 Arsenal          1          3   3749052   NaN        NaN
# 717                 Arsenal          1          3   3749052   NaN        NaN
# ...                     ...        ...        ...       ...   ...        ...
# 2059  United States Women's          1          2     69161   NaN        NaN
# 2211  United States Women's          1          2     69161   NaN        NaN
# 2227  United States Women's          1          2     69161   NaN        NaN
# 2432  United States Women's          1          2     69161   NaN        NaN
# 2504  United States Women's          1          2     69161   NaN        NaN
#
#      injury_stoppage half_end player_off
# 359              NaN      NaN        NaN
# 474              NaN      NaN        NaN
# 479              NaN      NaN        NaN
# 507              NaN      NaN        NaN
# 717              NaN      NaN        NaN
# ...              ...      ...        ...
# 2059             NaN      NaN        NaN
# 2211             NaN      NaN        NaN
# 2227             NaN      NaN        NaN
# 2432             NaN      NaN        NaN
# 2504             NaN      NaN        NaN
#
# [27741 rows x 47 columns]

# %%
df.to_pickle('shots_dataframe')

# %%
import pandas as pd
df = pd.read_pickle('shots_dataframe')
df #final data set with only shots taken examples
# Out:
#                                         id  index  period  \
# 359   b69245a8-00da-4bac-8766-7b1d7548acbc    360       1
# 474   86c1c1ba-71a9-401e-a11e-c43716c2f543    475       1
# 479   83491870-daa3-4174-b59a-f96d63c9881d    480       1
# 507   03f7b8ae-8f2d-448f-a75e-fb3aa350cb91    508       1
# 717   9d164056-1ab0-4e31-adfc-2c806537c0bd    718       1
# ...                                    ...    ...     ...
# 2059  3e767b66-7e5a-428e-a4a8-26af57a7639b   2060       2
# 2211  97ea84d3-d429-48a4-9664-a2c2d489da12   2212       2
# 2227  746bc451-30af-477a-b824-293543017741   2228       2
# 2432  a5a87567-a946-4860-9f5f-75436339c59d   2433       2
# 2504  b770310f-94c0-4397-ae2e-98d4ce86ace2   2505       2
#
#                    timestamp  minute  second                        type  \
# 359  2021-11-28 00:08:11.523       8      11  {'id': 16, 'name': 'Shot'}
# 474  2021-11-28 00:12:19.239      12      19  {'id': 16, 'name': 'Shot'}
# 479  2021-11-28 00:12:23.131      12      23  {'id': 16, 'name': 'Shot'}
# 507  2021-11-28 00:13:45.318      13      45  {'id': 16, 'name': 'Shot'}
# 717  2021-11-28 00:20:20.793      20      20  {'id': 16, 'name': 'Shot'}
# ...                      ...     ...     ...                         ...
# 2059 2021-11-28 00:14:29.178      59      29  {'id': 16, 'name': 'Shot'}
# 2211 2021-11-28 00:19:07.871      64       7  {'id': 16, 'name': 'Shot'}
# 2227 2021-11-28 00:19:59.455      64      59  {'id': 16, 'name': 'Shot'}
# 2432 2021-11-28 00:30:36.196      75      36  {'id': 16, 'name': 'Shot'}
# 2504 2021-11-28 00:33:35.925      78      35  {'id': 16, 'name': 'Shot'}
#
#       possession                                possession_team  \
# 359           22                   {'id': 1, 'name': 'Arsenal'}
# 474           28                   {'id': 1, 'name': 'Arsenal'}
# 479           28                   {'id': 1, 'name': 'Arsenal'}
# 507           32  {'id': 46, 'name': 'Wolverhampton Wanderers'}
# 717           48  {'id': 46, 'name': 'Wolverhampton Wanderers'}
# ...          ...                                            ...
# 2059         118  {'id': 1214, 'name': 'United States Women's'}
# 2211         126  {'id': 1214, 'name': 'United States Women's'}
# 2227         128           {'id': 863, 'name': 'Spain Women's'}
# 2432         138  {'id': 1214, 'name': 'United States Women's'}
# 2504         143  {'id': 1214, 'name': 'United States Women's'}
#
#                              play_pattern  ...                home_team  \
# 359    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 474    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 479    {'id': 4, 'name': 'From Throw In'}  ...  Wolverhampton Wanderers
# 507   {'id': 3, 'name': 'From Free Kick'}  ...  Wolverhampton Wanderers
# 717   {'id': 3, 'name': 'From Free Kick'}  ...  Wolverhampton Wanderers
# ...                                   ...  ...                      ...
# 2059  {'id': 3, 'name': 'From Free Kick'}  ...            Spain Women's
# 2211   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
# 2227   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
# 2432           {'id': 5, 'name': 'Other'}  ...            Spain Women's
# 2504   {'id': 4, 'name': 'From Throw In'}  ...            Spain Women's
#
#                   away_team home_score away_score  match_id 50_50 half_start  \
# 359                 Arsenal          1          3   3749052   NaN        NaN
# 474                 Arsenal          1          3   3749052   NaN        NaN
# 479                 Arsenal          1          3   3749052   NaN        NaN
# 507                 Arsenal          1          3   3749052   NaN        NaN
# 717                 Arsenal          1          3   3749052   NaN        NaN
# ...                     ...        ...        ...       ...   ...        ...
# 2059  United States Women's          1          2     69161   NaN        NaN
# 2211  United States Women's          1          2     69161   NaN        NaN
# 2227  United States Women's          1          2     69161   NaN        NaN
# 2432  United States Women's          1          2     69161   NaN        NaN
# 2504  United States Women's          1          2     69161   NaN        NaN
#
#      injury_stoppage half_end player_off
# 359              NaN      NaN        NaN
# 474              NaN      NaN        NaN
# 479              NaN      NaN        NaN
# 507              NaN      NaN        NaN
# 717              NaN      NaN        NaN
# ...              ...      ...        ...
# 2059             NaN      NaN        NaN
# 2211             NaN      NaN        NaN
# 2227             NaN      NaN        NaN
# 2432             NaN      NaN        NaN
# 2504             NaN      NaN        NaN
#
# [27741 rows x 47 columns]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
y = df['shot'].values
X = df.iloc[:, df.columns!='shot']

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c045ad2b97e3> in <module>
#       5
#       6 X_train, X_test, y_train, y_test = \
# ----> 7     train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42, stratify=y)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2195                      random_state=random_state)
#    2196
# -> 2197         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2198
#    2199     return list(chain.from_iterable((_safe_indexing(a, train),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1385         """
#    1386         X, y, groups = indexable(X, y, groups)
# -> 1387         for train, test in self._iter_indices(X, y, groups):
#    1388             yield train, test
#    1389
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1708             y = np.array([' '.join(row.astype('str')) for row in y])
#    1709
# -> 1710         classes, y_indices = np.unique(y, return_inverse=True)
#    1711         n_classes = classes.shape[0]
#    1712
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     318
#     319     if optional_indices:
# --> 320         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     321         aux = ar[perm]
#     322     else:
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %%
df['shot'].values #under 'outcome' there is 'name' which says whether there was a goal or not
#I thought we'd split the data set up like that
# Out:
# array([{'statsbomb_xg': 0.18677612000000002, 'end_location': [120.0, 43.8, 0.5], 'key_pass_id': '8267672c-804d-4702-ac50-d501f2eb8fe2', 'body_part': {'id': 40, 'name': 'Right Foot'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 97, 'name': 'Goal'}, 'first_time': True, 'technique': {'id': 91, 'name': 'Half Volley'}, 'freeze_frame': [{'location': [104.0, 29.4], 'player': {'id': 24765, 'name': 'Denis Irwin'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': False}, {'location': [101.9, 50.4], 'player': {'id': 40304, 'name': 'Lee Naylor'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': False}, {'location': [97.8, 39.3], 'player': {'id': 40313, 'name': 'Colin Cameron'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [105.2, 39.6], 'player': {'id': 40312, 'name': 'Paul Butler'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [107.2, 31.4], 'player': {'id': 40314, 'name': 'Jody Craddock'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [114.7, 37.1], 'player': {'id': 40319, 'name': 'Paul Jones'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [106.8, 27.7], 'player': {'id': 12529, 'name': 'Ashley Cole'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': True}, {'location': [98.9, 35.0], 'player': {'id': 19312, 'name': 'Robert Pirès '}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'teammate': True}]},
#        {'statsbomb_xg': 0.031963106000000005, 'end_location': [118.7, 38.9, 2.3], 'key_pass_id': '428a30a1-5f57-4b04-ab1b-5f0a3e189d36', 'technique': {'id': 93, 'name': 'Normal'}, 'body_part': {'id': 40, 'name': 'Right Foot'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 100, 'name': 'Saved'}, 'freeze_frame': [{'location': [110.2, 41.
}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [107.1, 52.0], 'player': {'id': 5013, 'name': 'Tobin Powell Heath'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': True}, {'location': [95.9, 46.3], 'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': False}, {'location': [108.5, 31.6], 'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': False}, {'location': [109.2, 18.9], 'player': {'id': 10200, 'name': 'Marta Corredera Rueda'}, 'position': {'id': 2, 'name': 'Right Back'}, 'teammate': False}, {'location': [113.6, 30.2], 'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [111.5, 40.4], 'player': {'id': 10155, 'name': 'María Pilar León Cebrián'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [118.6, 36.4], 'player': {'id': 10142, 'name': 'Sandra Paños García-Villamil'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [109.0, 50.7], 'player': {'id': 10163, 'name': 'Leila Ouahabi El Ouahabi'}, 'position': {'id': 6, 'name': 'Left Back'}, 'teammate': False}, {'location': [89.3, 57.1], 'player': {'id': 25842, 'name': 'Andrea Sánchez Falcón'}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'teammate': False}]}],
#       dtype=object)

# %%
import numpy as np
indices = df['match_id'].unique()
rnd = np.random.RandomState(42)
shuffled_indices = rnd.permutation(indices)
shuffled_indices
# Out:
# array([3749052, 3749522, 3749246, ...,   69284,   69205,   69161])

# %%
X_shuffled, y_shuffled = [shuffled_indices], df.loc['match_id'][shuffled_indices]
X_train, y_train = X_shuffled[:766], y_shuffled[:766]
X_test, y_test = X_shuffled[329:], y_shuffled[329:]
X_test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-69a2a827767c> in <module>
# ----> 1 X_shuffled, y_shuffled = df.loc[:, df.columns!='match_id'][shuffled_indices], df.loc['match_id'][shuffled_indices]
#       2 X_train, y_train = X_shuffled[:766], y_shuffled[:766]
#       3 X_test, y_test = X_shuffled[329:], y_shuffled[329:]
#       4 X_test
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Int64Index([  69343,  267183,   68358, 2275037,    7474, 3788752, 3773672,\n            3764236,   69188,   19739,\n            ...\n              70301,   19790,   69292, 2275038,   69182,   70286,  303400,\n              69214,   68357, 2275061],\n           dtype='int64', length=1095)] are in the [columns]"

# %%
a = df['match_id'].unique()
a[]
# Out:
# array([3749052, 3749522, 3749246, ...,   69284,   69205,   69161])

# %%
a=df[df['match_id']==7298]
a['shot'].values
# Out:
# array([{'statsbomb_xg': 0.09262405, 'end_location': [117.0, 34.0], 'key_pass_id': 'abb17b2a-1775-4226-9158-67efe68ee0c3', 'body_part': {'id': 40, 'name': 'Right Foot'}, 'technique': {'id': 93, 'name': 'Normal'}, 'type': {'id': 87, 'name': 'Open Play'}, 'outcome': {'id': 96, 'name': 'Blocked'}, 'freeze_frame': [{'location': [115.0, 36.0], 'player': {'id': 17524, 'name': 'Jennifer Patricia Beattie'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location':