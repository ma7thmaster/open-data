# %%
import requests

response = requests.get(target_url)
data = response.text

# %%
import pandas as pd #matches data
import json
path_to_jsonfiles = 'open-data/data/matches/2'
alldic2 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic2.append(dict)
var7=pd.concat(alldic2)

path_to_jsonfiles = 'open-data/data/matches/11'
alldicts = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldicts.append(dict)

        
var=pd.concat(alldicts)
#var
path_to_jsonfiles = 'open-data/data/matches/16'
alldic = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic.append(dict)
var1=pd.concat(alldic)
#com = [var,var1]
#varcom = pd.concat(com)

path_to_jsonfiles = 'open-data/data/matches/37'
alldic37 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic37.append(dict)
var2=pd.concat(alldic37)

path_to_jsonfiles = '/open-data/data/matches/43'
alldic43 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic43.append(dict)
var3=pd.concat(alldic43)

path_to_jsonfiles = 'open-data/data/matches/49'
alldic49 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic49.append(dict)
var4=pd.concat(alldic49)

path_to_jsonfiles = 'open-data/data/matches/55'
alldic55 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic55.append(dict)
var5=pd.concat(alldic55)

path_to_jsonfiles = 'open-data/data/matches/72'
alldic72 = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldic72.append(dict)
var6=pd.concat(alldic72)

com = [var7,var,var1,var2,var3,var4,var5,var6]
matchestogether = pd.concat(com)
matchestogether=matchestogether.reset_index()
matchestogether
#matches=matchestogether.to_json(orient='columns') #leider funktioniert das noch nicht!
# Out:
#       index  match_id  match_date      kick_off  \
# 0         0   3749052  2004-02-07  16:00:00.000
# 1         1   3749522  2003-12-26  13:00:00.000
# 2         2   3749246  2004-03-28  17:05:00.000
# 3         3   3749257  2004-05-15  16:00:00.000
# 4         4   3749642  2004-02-28  16:00:00.000
# ...     ...       ...         ...           ...
# 1090     47     69199  2019-06-27  21:00:00.000
# 1091     48     69258  2019-07-02  21:00:00.000
# 1092     49     69284  2019-07-03  21:00:00.000
# 1093     50     69205  2019-06-29  15:00:00.000
# 1094     51     69161  2019-06-24  18:00:00.000
#
#                                             competition  \
# 0     {'competition_id': 2, 'country_name': 'England...
# 1     {'competition_id': 2, 'country_name': 'England...
# 2     {'competition_id': 2, 'country_name': 'England...
# 3     {'competition_id': 2, 'country_name': 'England...
# 4     {'competition_id': 2, 'country_name': 'England...
# ...

# %%
import pandas as pd #lineups
path_to_json = 'open-data/data/lineups'
alldicline = []
for file in os.listdir(path_to_jsonfiles):
    full_filename = "%s/%s" % (path_to_jsonfiles, file)
    with open(full_filename,'r') as fi:
        dict = pd.read_json(fi)
        alldicline.append(dict)
varlineup=pd.concat(alldicline)
varlineup = varlineup.reset_index()
varlineup
# Out:
#     index  match_id  match_date      kick_off  \
# 0       0     68311  2019-06-18  21:00:00.000
# 1       1     68357  2019-06-22  21:00:00.000
# 2       2     22933  2019-06-09  13:00:00.000
# 3       3     22940  2019-06-10  18:00:00.000
# 4       4     22943  2019-06-11  21:00:00.000
# 5       5     22944  2019-06-11  18:00:00.000
# 6       6     22945  2019-06-12  15:00:00.000
# 7       7     22949  2019-06-12  18:00:00.000
# 8       8     22956  2019-06-13  21:00:00.000
# 9       9     22963  2019-06-14  18:00:00.000
# 10     10     22961  2019-06-14  15:00:00.000
# 11     11     22964  2019-06-15  15:00:00.000
# 12     12     22966  2019-06-15  21:00:00.000
# 13     13     68344  2019-06-20  18:00:00.000
# 14     14     68345  2019-06-20  21:00:00.000
# 15     15     69163  2019-06-24  21:00:00.000
# 16     16     68346  2019-06-20  18:00:00.000
# 17     17     68355  2019-06-22  17:30:00.000
# 18     18     69301  2019-07-06  17:00:00.000
# ...

# %%
tes = pd.read_json('open-data/data/events/7298.json')
tes['adder']=None
for i in range(len(tes)):
    tes.at[i,'adder']=7298 #How to find the file name and use just the id value?
tes
# Out:
#                                         id  index  period  \
# 0     bfa58325-4dc1-422d-9ac6-384c115434c0      1       1
# 1     588860a8-3728-48c2-a049-6e5a68da8653      2       1
# 2     f357652b-ae75-4848-ab65-68952fb9d7ba      3       1
# 3     958aeea0-003a-4796-98dd-2f7d2de4a57a      4       1
# 4     60d35b7c-3b85-42da-9af8-a74a21d8f7ca      5       1
# ...                                    ...    ...     ...
# 3788  3163b5be-db77-46d1-b7e7-9d31480366e1   3789       2
# 3789  e58b1f47-9d9c-4afc-a7f2-3c86fd756bf0   3790       2
# 3790  5e4e4b2e-7bb3-4212-abd5-6bee0da156d2   3791       2
# 3791  30c14d7a-1555-40e7-b4c0-6a218dc0e5f5   3792       2
# 3792  36ae73ea-81b8-4d1a-a438-704fab138799   3793       2
#
#                    timestamp  minute  second  \
# 0    2021-11-20 00:00:00.000       0       0
# 1    2021-11-20 00:00:00.000       0       0
# 2    2021-11-20 00:00:00.000       0       0
# 3    2021-11-20 00:00:00.000       0       0
# ...

# %%
for(matchestogether
